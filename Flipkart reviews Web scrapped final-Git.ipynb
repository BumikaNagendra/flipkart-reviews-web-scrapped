# %% [markdown]
# <table>
#     <tr>
#         <td>
#             <div align ="center">
#                 <font color="orange" size=8px>
#                     <b> NLP Project on <br> Flipkart reviews sentiment Analysis
#                     </b>
#                 </font>
#             </div>
#         </td>
#     <tr>
# <table>

# %% [markdown]
# ### <font color=orange> Problem Statement </font> :
#
# Analysing Customer's choice for Flipkart based on the reviews and ratings.
#
# Evaluation of an individual's sentiment from a piece of text is challenging.
#
# Sentiment analysis is necessary to get customer feelings,attitudes, reactions, and opinions of existing and potential buyers towards flipkart's products or services.
#
# So lets apply the NLP techniques to analyze the customer reviews in Flipkart.

# %% [markdown]
# # Flipkart Electronics reviews Web scrapped Data

# %% [markdown]
# ##### Importing required libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

# %% [markdown]
# ### Product 1 : wired headset

# %%
df=pd.DataFrame()
for i in range(1,520):
    url='https://www.flipkart.com/redmi-mi-hi-resolution-audio-wired-headset/product-reviews/itmfc704fbf24f2c?pid=ACCFUT9HGEZ5XNKZ&lid=LSTACCFUT9HGEZ5XNKZLFX2ZK&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df=df.append(temp, ignore_index=True)
        
df[['review_title','review','rate','category']]
df['rating']=df['rate'].str.extract('(\d+)')

df.head()
# Out:
#                                      category                    rate  \
# 0  redmi-mi-hi-resolution-audio-wired-headset  2Slightly disappointed
# 1  redmi-mi-hi-resolution-audio-wired-headset          5Great product
# 2  redmi-mi-hi-resolution-audio-wired-headset              5Must buy!
# 3  redmi-mi-hi-resolution-audio-wired-headset            4Good choice
# 4  redmi-mi-hi-resolution-audio-wired-headset             4Delightful
#
#                                               review           review_title  \
# 0  Kinda good with great sound effects three diff...  Slightly disappointed
# 1  Very good product and sound quality is very ni...          Great product
# 2  Redmi Earphones is the best earphones I have u...              Must buy!
# 3  Red colour looks stunning 😍.Sound quality is c...            Good choice
# 4  Though I have received it today, they were run...             Delightful
#
#   rating
# 0      2
# 1      5
# 2      5
# 3      4
# 4      4

# %%
df.shape
# Out:
# (4997, 5)

# %%
df.head()
# Out:
#                                      category                    rate  \
# 0  redmi-mi-hi-resolution-audio-wired-headset  2Slightly disappointed
# 1  redmi-mi-hi-resolution-audio-wired-headset          5Great product
# 2  redmi-mi-hi-resolution-audio-wired-headset              5Must buy!
# 3  redmi-mi-hi-resolution-audio-wired-headset            4Good choice
# 4  redmi-mi-hi-resolution-audio-wired-headset             4Delightful
#
#                                               review           review_title  \
# 0  Kinda good with great sound effects three diff...  Slightly disappointed
# 1  Very good product and sound quality is very ni...          Great product
# 2  Redmi Earphones is the best earphones I have u...              Must buy!
# 3  Red colour looks stunning 😍.Sound quality is c...            Good choice
# 4  Though I have received it today, they were run...             Delightful
#
#   rating
# 0      2
# 1      5
# 2      5
# 3      4
# 4      4

# %% [markdown]
# ### Product 2: Power Bank

# %%
df1=pd.DataFrame()
for i in range(1,783):  #number of review pages for this product=782
    url='https://www.flipkart.com/mi-3i-20000-mah-power-bank-fast-charging-18w/product-reviews/itmff9ed1f750abc?pid=PWBFVGXXFGEBYRF5&lid=LSTPWBFVGXXFGEBYRF514LSY9&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df1=df1.append(temp, ignore_index=True)
        
df1[['review_title','review','rate','category']]
df1['rating']=df1['rate'].str.extract('(\d+)')  #extracting only numeric value for rating from rate column

df1.head()
# Out:
#                                        category                   rate  \
# 0  mi-3i-20000-mah-power-bank-fast-charging-18w  4Good quality product
# 1  mi-3i-20000-mah-power-bank-fast-charging-18w             5Fabulous!
# 2  mi-3i-20000-mah-power-bank-fast-charging-18w          4Nice product
# 3  mi-3i-20000-mah-power-bank-fast-charging-18w                5Super!
# 4  mi-3i-20000-mah-power-bank-fast-charging-18w             5Must buy!
#
#                                               review          review_title  \
# 0  * best battery life * good performance* value ...  Good quality product
# 1  Best power and fast charging i love this produ...             Fabulous!
# 2  Pros: 1.Charging time with 18W charger is 7 ho...          Nice product
# 3  Good product 20000mAh power bank. And original...                Super!
# 4  Thank you so much Flipkart this is a great pow...             Must buy!
#
#   rating
# 0      4
# 1      5
# 2      4
# 3      5
# 4      5

# %%
print(df1.shape)
# Out:
# (7507, 5)

# %%
a1=pd.concat([df,df1],ignore_index=True) #combining the two dataframes
print(a1.shape)
a1.head()
# Out:
# (12504, 5)
#                                      category                    rate  \
# 0  redmi-mi-hi-resolution-audio-wired-headset  2Slightly disappointed
# 1  redmi-mi-hi-resolution-audio-wired-headset          5Great product
# 2  redmi-mi-hi-resolution-audio-wired-headset              5Must buy!
# 3  redmi-mi-hi-resolution-audio-wired-headset            4Good choice
# 4  redmi-mi-hi-resolution-audio-wired-headset             4Delightful
#
#                                               review           review_title  \
# 0  Kinda good with great sound effects three diff...  Slightly disappointed
# 1  Very good product and sound quality is very ni...          Great product
# 2  Redmi Earphones is the best earphones I have u...              Must buy!
# 3  Red colour looks stunning 😍.Sound quality is c...            Good choice
# 4  Though I have received it today, they were run...             Delightful
#
#   rating
# 0      2
# 1      5
# 2      5
# 3      4
# 4      4

# %% [markdown]
# ### Product 3: Apple watch

# %%
df2=pd.DataFrame()
for i in range(1,387):  
    url='https://www.flipkart.com/apple-watch-series-3-gps-42-mm-space-grey-aluminium-case-black-sport-band/product-reviews/itm91c560e722cdd?pid=SMWF94AYMNYHTYDJ&lid=LSTSMWF94AYMNYHTYDJU9ZHY3&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df2=df2.append(temp, ignore_index=True)
        
df2[['review_title','review','rate','category']]
df2['rating']=df2['rate'].str.extract('(\d+)')

df2.head()
# Out:
#                                             category                rate  \
# 0  apple-watch-series-3-gps-42-mm-space-grey-alum...   5Perfect product!
# 1  apple-watch-series-3-gps-42-mm-space-grey-alum...     5Classy product
# 2  apple-watch-series-3-gps-42-mm-space-grey-alum...     5Classy product
# 3  apple-watch-series-3-gps-42-mm-space-grey-alum...           5Terrific
# 4  apple-watch-series-3-gps-42-mm-space-grey-alum...  5Terrific purchase
#
#                                               review       review_title rating
# 0  Thank you for delivery it just in one day . I ...   Perfect product!      5
# 1  Superb Quality , Nothing like apple , No need ...     Classy product      5
# 2  Apple does seem to release stable product over...     Classy product      5
# 3  My First Apple Watch!!! Simply Amazing.I used ...           Terrific      5
# 4  Seriously I can’t express my inner feelings......  Terrific purchase      5

# %%
df2.shape
# Out:
# (3854, 5)

# %%
a2=pd.concat([a1,df2],ignore_index=True)
print(a2.shape)
#a2.head()
# Out:
# (16358, 5)

# %% [markdown]
# ### Product 4: Mobile Holder

# %%
df3=pd.DataFrame()
for i in range(1,438):  
    url='https://www.flipkart.com/portronics-por-122-modesk-universal-mobile-holder-black/product-reviews/itmfdbm8axuvkey6?pid=MOHFDB7TUX5VHBMW&lid=LSTMOHFDB7TUX5VHBMWTRRZHM&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df3=df3.append(temp, ignore_index=True)
        
df3[['review_title','review','rate','category']]
df3['rating']=df3['rate'].str.extract('(\d+)')

df3.head()
# Out:
#                                             category                  rate  \
# 0  portronics-por-122-modesk-universal-mobile-hol...       5Classy product
# 1  portronics-por-122-modesk-universal-mobile-hol...  5Best in the market!
# 2  portronics-por-122-modesk-universal-mobile-hol...       3Decent product
# 3  portronics-por-122-modesk-universal-mobile-hol...    5Terrific purchase
# 4  portronics-por-122-modesk-universal-mobile-hol...            5Brilliant
#
#                                               review         review_title  \
# 0  Good quality product by this companyThe build ...       Classy product
# 1  Good product. Made up of good metal. Have a ni...  Best in the market!
# 2  Product quality is good but it should be give ...       Decent product
# 3  Perfect product. At a good price. Sturdy build...    Terrific purchase
# 4  Excellent finish, sturdy, correctly weighted t...            Brilliant
#
#   rating
# 0      5
# 1      5
# 2      3
# 3      5
# 4      5

# %%
df3.shape
# Out:
# (4144, 5)

# %%
a3=pd.concat([a2,df3],ignore_index=True)
print(a3.shape)
# Out:
# (20502, 5)

# %% [markdown]
# ### Product 5: BP Monitor

# %%
df4=pd.DataFrame()
for i in range(1,314):  
    url='https://www.flipkart.com/omron-hem-7124-bp-monitor/product-reviews/itmeh7sqdjzuuw9h?pid=BPMEH7SQU5GDJZHS&lid=LSTBPMEH7SQU5GDJZHSOVTPUB&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df4=df4.append(temp, ignore_index=True)
        
df4[['review_title','review','rate','category']]
df4['rating']=df4['rate'].str.extract('(\d+)')

df4.head()
# Out:
#                     category                rate  \
# 0  omron-hem-7124-bp-monitor  5Worth every penny
# 1  omron-hem-7124-bp-monitor        4Pretty good
# 2  omron-hem-7124-bp-monitor            5Awesome
# 3  omron-hem-7124-bp-monitor          4Very Good
# 4  omron-hem-7124-bp-monitor      5Great product
#
#                                               review       review_title rating
# 0  nice packaging and this dp monitor are very us...  Worth every penny      5
# 1  Received the product today. In absolutely good...        Pretty good      4
# 2  good one with good and almost accurate reading...            Awesome      5
# 3  overall good but u have to check bp 2 times in...          Very Good      4
# 4  Amazing Delivery at such a Lockdown time...Rea...      Great product      5

# %%
df4.shape
# Out:
# (3120, 5)

# %%
a4=pd.concat([a3,df4],ignore_index=True)
print(a4.shape)
# Out:
# (23622, 5)

# %% [markdown]
# ### Product 6: External hard disk

# %%
df5=pd.DataFrame()
for i in range(1,319):  
    url='https://www.flipkart.com/seagate-backup-plus-slim-1-tb-external-hard-disk-drive/product-reviews/itmffueqescquj7f?pid=ACCFFUEQQHZHTUCB&lid=LSTACCFFUEQQHZHTUCBMHXW6Q&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df5=df5.append(temp, ignore_index=True)
        
df5[['review_title','review','rate','category']]
df5['rating']=df5['rate'].str.extract('(\d+)')

df5.head()
# Out:
#                                             category                     rate  \
# 0  seagate-backup-plus-slim-1-tb-external-hard-di...               5Wonderful
# 1  seagate-backup-plus-slim-1-tb-external-hard-di...                 5Awesome
# 2  seagate-backup-plus-slim-1-tb-external-hard-di...            3Does the job
# 3  seagate-backup-plus-slim-1-tb-external-hard-di...     5Best in the market!
# 4  seagate-backup-plus-slim-1-tb-external-hard-di...  1Not recommended at all
#
#                                               review            review_title  \
# 0  I have been using this since the last 3 weeks....               Wonderful
# 1  Wonderful product... best in this price range....                 Awesome
# 2  Light weight and handy one.....with 1.8 tb of ...            Does the job
# 3  very Satisfied with the product. Speed is good...     Best in the market!
# 4  This hard disk has been became defective once ...  Not recommended at all
#
#   rating
# 0      5
# 1      5
# ...

# %%
df5.shape
# Out:
# (3154, 5)

# %%
a5=pd.concat([a4,df5],ignore_index=True)
print(a5.shape)
# Out:
# (26776, 5)

# %% [markdown]
# ### Product 7: Wired mouse

# %%
df6=pd.DataFrame()
for i in range(1,524):  
    url='https://www.flipkart.com/dell-ms-116-wired-optical-mouse/product-reviews/itmekm2ggehfhfaw?pid=ACCEKM2GZAGFW2TM&lid=LSTACCEKM2GZAGFW2TMF3S8CR&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df6=df6.append(temp, ignore_index=True)
        
df6[['review_title','review','rate','category']]

df6['rating']=df6['rate'].str.extract('(\d+)')

df6.head()
# Out:
#                           category                rate  \
# 0  dell-ms-116-wired-optical-mouse  5Worth every penny
# 1  dell-ms-116-wired-optical-mouse          5Brilliant
# 2  dell-ms-116-wired-optical-mouse             5Super!
# 3  dell-ms-116-wired-optical-mouse  5Worth every penny
# 4  dell-ms-116-wired-optical-mouse   5Perfect product!
#
#                                               review       review_title rating
# 0  Bestest wired (🐁 ) mouse everPoints1. I like i...  Worth every penny      5
# 1  Original StuffSuperb Classic Design, Best Touc...          Brilliant      5
# 2  Nice product received from Dell...Dell is one ...             Super!      5
# 3  Decent mouse with smooth movement..Nothing els...  Worth every penny      5
# 4  Easy to use, the performance is good , it is c...   Perfect product!      5

# %%
df6.shape
# Out:
# (5142, 5)

# %%
a6=pd.concat([a5,df6],ignore_index=True)
print(a6.shape)
# Out:
# (31918, 5)

# %% [markdown]
# ### Product 8: Printer

# %%
df7=pd.DataFrame()
for i in range(1,204):  
    url='https://www.flipkart.com/epson-l3110-multi-function-color-printer/product-reviews/itmfb28z2g9ygubg?pid=PRNFB28YS326QDZF&lid=LSTPRNFB28YS326QDZF5KC7M2&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df7=df7.append(temp, ignore_index=True)
        
df7[['review_title','review','rate','category']]
df7['rating']=df7['rate'].str.extract('(\d+)')

df7.head()
# Out:
#                                    category           rate  \
# 0  epson-l3110-multi-function-color-printer     5Must buy!
# 1  epson-l3110-multi-function-color-printer     4Wonderful
# 2  epson-l3110-multi-function-color-printer     1Very poor
# 3  epson-l3110-multi-function-color-printer     5Brilliant
# 4  epson-l3110-multi-function-color-printer  4Nice product
#
#                                               review  review_title rating
# 0  Great printer. The color reproduction on the p...     Must buy!      5
# 1  good priinter at the pricebut as i expect ink ...     Wonderful      4
# 2  Not a very user friendly printer..Canon in thi...     Very poor      1
# 3  It is very good Products and its printing qual...     Brilliant      5
# 4  printer works very well.. great quality... per...  Nice product      4

# %%
df7.shape
# Out:
# (2011, 5)

# %%
a7=pd.concat([a6,df7],ignore_index=True)
print(a7.shape)
# Out:
# (33929, 5)

# %% [markdown]
# ### Product 9: Digital Weighing Scale

# %%
df8=pd.DataFrame()
for i in range(1,668):  
    url='https://www.flipkart.com/dr-trust-usa-executive-rechargeable-digital-weighing-scale-electronic-weight-machine-human-body-temperature-display-usb-cable-included/product-reviews/itm23f04b83d31ee?pid=WSLF63F5AYBDEEGJ&lid=LSTWSLF63F5AYBDEEGJULFQKJ&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df8=df8.append(temp, ignore_index=True)
        
df8[['review_title','review','rate','category']]
df8['rating']=df8['rate'].str.extract('(\d+)')

df8.head()
# Out:
#                                             category                   rate  \
# 0  dr-trust-usa-executive-rechargeable-digital-we...  1Utterly Disappointed
# 1  dr-trust-usa-executive-rechargeable-digital-we...             5Just wow!
# 2  dr-trust-usa-executive-rechargeable-digital-we...             1Worthless
# 3  dr-trust-usa-executive-rechargeable-digital-we...               5Awesome
# 4  dr-trust-usa-executive-rechargeable-digital-we...            4Delightful
#
#                                               review          review_title  \
# 0  It's not good please don't go for it.. Weighin...  Utterly Disappointed
# 1  I got this weight machine on April 25. The bui...             Just wow!
# 2  Waste of money, time and energyThe machine wor...             Worthless
# 3  Excellent product , received it in very good c...               Awesome
# 4  My first product is rip in just 3 week. But th...            Delightful
#
#   rating
# 0      1
# 1      5
# 2      1
# 3      5
# ...

# %%
df8.shape
# Out:
# (6588, 5)

# %%
a8=pd.concat([a7,df8],ignore_index=True)
print(a8.shape)
# Out:
# (40517, 5)

# %% [markdown]
# ### Product 10: Pendrive

# %%
df9=pd.DataFrame()
for i in range(1,668):  
    url='https://www.flipkart.com/sandisk-sdcz50-064g-i35-sdcz50-064g-b35-64-gb-pen-drive/product-reviews/itmf3qyaaqr5azmn?pid=ACCDZ583WDDSDY3F&lid=LSTACCDZ583WDDSDY3F3ITXX5&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df9=df9.append(temp, ignore_index=True)
        
df9[['review_title','review','rate','category']]
df9['rating']=df9['rate'].str.extract('(\d+)')

df9.head()
# Out:
#                                             category                rate  \
# 0  sandisk-sdcz50-064g-i35-sdcz50-064g-b35-64-gb-...     5Simply awesome
# 1  sandisk-sdcz50-064g-i35-sdcz50-064g-b35-64-gb-...        4Pretty good
# 2  sandisk-sdcz50-064g-i35-sdcz50-064g-b35-64-gb-...   5Perfect product!
# 3  sandisk-sdcz50-064g-i35-sdcz50-064g-b35-64-gb-...           2Not good
# 4  sandisk-sdcz50-064g-i35-sdcz50-064g-b35-64-gb-...  5Value for money..
#
#                                               review       review_title rating
# 0  SanDisk is a nice brand...64gb pendrive i have...     Simply awesome      5
# 1  After a day of use reading fast writing speed ...        Pretty good      4
# 2  It was good .EVEN DELIVERY EXPERIENCE WAS ALSO...   Perfect product!      5
# 3  I bought this pendrive for my VU TV but it's n...           Not good      2
# 4  Best in the price range compared to other bran...  Value for money..      5

# %%
df9.shape
# Out:
# (6566, 5)

# %%
a9=pd.concat([a8,df9],ignore_index=True)
print(a9.shape)
# Out:
# (47083, 5)

# %% [markdown]
# ### Product 11: Camera

# %%
df10=pd.DataFrame()
for i in range(1,337):  
    url='https://www.flipkart.com/canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens/product-reviews/itm6f665fea97bc2?pid=CAMF3DHJURPEMNRN&lid=LSTCAMF3DHJURPEMNRNYD4BKP&marketplace=FLIPKART&page={}'.format(i)
    category=url.split('/')[3]
    HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
    
    data = requests.get(url,headers=HEADERS)
    soup = BeautifulSoup(data.content)
    category=url.split('/')[3]
    parent_tags=soup.findAll('div',{'class':'col _2wzgFH K0kLPL'})
    
    for parent in parent_tags:
        try:
            review_headline=parent.find('p',{'class':'_2-N8zT'}).text
        except:
            review_headline=None
        try:
            review=parent.find('div',{'class':'t-ZTKy'}).text
        except:
            review=None
        try:
            rate=parent.select_one('div',{'class':'_3LWZlK _1BLPMq','class':'_3LWZlK _1rdVr6 _1BLPMq'}).text
                
        except:
            rate=None
    
        temp={
        'review_title':review_headline,
        'review':review,
        'rate':rate,
        'category':category}
        
        df10=df10.append(temp, ignore_index=True)
        
df10[['review_title','review','rate','category']]
df10['rating']=df10['rate'].str.extract('(\d+)')

df10.head()
# Out:
#                                            category                  rate  \
# 0  canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens            5Excellent
# 1  canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens         3Does the job
# 2  canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens      4Worth the money
# 3  canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens            5Just wow!
# 4  canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens  5Best in the market!
#
#                                               review         review_title  \
# 0  product really great . I am totally sctified t...            Excellent
# 1  Satisfied with the product.. Its a really good...         Does the job
# 2  The camera simply awesome..and it is a best bu...      Worth the money
# 3  Worth more than the amount. Best DSLR for a go...            Just wow!
# 4  product is very good and build quality also , ...  Best in the market!
#
#   rating
# 0      5
# 1      3
# 2      4
# 3      5
# 4      5

# %%
df10.shape
# Out:
# (3352, 5)

# %%
a10=pd.concat([a9,df10],ignore_index=True)
print(a10.shape)
# Out:
# (50435, 5)

# %%
rev=a10.copy()

# %%
rev.head()
# Out:
#                                      category                    rate  \
# 0  redmi-mi-hi-resolution-audio-wired-headset  2Slightly disappointed
# 1  redmi-mi-hi-resolution-audio-wired-headset          5Great product
# 2  redmi-mi-hi-resolution-audio-wired-headset              5Must buy!
# 3  redmi-mi-hi-resolution-audio-wired-headset            4Good choice
# 4  redmi-mi-hi-resolution-audio-wired-headset             4Delightful
#
#                                               review           review_title  \
# 0  Kinda good with great sound effects three diff...  Slightly disappointed
# 1  Very good product and sound quality is very ni...          Great product
# 2  Redmi Earphones is the best earphones I have u...              Must buy!
# 3  Red colour looks stunning 😍.Sound quality is c...            Good choice
# 4  Though I have received it today, they were run...             Delightful
#
#   rating
# 0      2
# 1      5
# 2      5
# 3      4
# 4      4

# %%
rev.shape
# Out:
# (50435, 5)

# %%
rev=rev.drop('rate',axis=1)

# %%
rev.head()
# Out:
#                                      category  \
# 0  redmi-mi-hi-resolution-audio-wired-headset
# 1  redmi-mi-hi-resolution-audio-wired-headset
# 2  redmi-mi-hi-resolution-audio-wired-headset
# 3  redmi-mi-hi-resolution-audio-wired-headset
# 4  redmi-mi-hi-resolution-audio-wired-headset
#
#                                               review           review_title  \
# 0  Kinda good with great sound effects three diff...  Slightly disappointed
# 1  Very good product and sound quality is very ni...          Great product
# 2  Redmi Earphones is the best earphones I have u...              Must buy!
# 3  Red colour looks stunning 😍.Sound quality is c...            Good choice
# 4  Though I have received it today, they were run...             Delightful
#
#   rating
# 0      2
# 1      5
# 2      5
# 3      4
# 4      4

# %%
rev.shape
# Out:
# (50435, 4)

# %%
rev.to_csv('flipkart_reviews.csv') #converting dataframe to csv file

# %%
fp=pd.read_csv('flipkart_reviews.csv')  #loading and checking the csv file
fp.head()
# Out:
#    Unnamed: 0                                    category  \
# 0           0  redmi-mi-hi-resolution-audio-wired-headset
# 1           1  redmi-mi-hi-resolution-audio-wired-headset
# 2           2  redmi-mi-hi-resolution-audio-wired-headset
# 3           3  redmi-mi-hi-resolution-audio-wired-headset
# 4           4  redmi-mi-hi-resolution-audio-wired-headset
#
#                                               review           review_title  \
# 0  Kinda good with great sound effects three diff...  Slightly disappointed
# 1  Very good product and sound quality is very ni...          Great product
# 2  Redmi Earphones is the best earphones I have u...              Must buy!
# 3  Red colour looks stunning 😍.Sound quality is c...            Good choice
# 4  Though I have received it today, they were run...             Delightful
#
#    rating
# 0       2
# 1       5
# 2       5
# 3       4
# 4       4
